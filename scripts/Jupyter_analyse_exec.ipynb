# %%
#Télécharger le dossier git
# !git clone https://github.com/thomasripoll91-star/freelance-demo

#Se placer dans ce dossier
# %cd freelance-demo/

#Tester si les bons fichiers existent
# %ls

# %%
from function_analyst import Analyst

analyste = Analyst("../data/fifa21.csv")
analyste.start_analyse()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_14640/4151377682.py in <cell line: 0>()
# ----> 1 from function_analyst import Analyst
#       2
#       3 analyste = Analyst("../data/fifa21.csv")
#       4 analyste.start_analyse()
#
# ModuleNotFoundError: No module named 'function_analyst'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
